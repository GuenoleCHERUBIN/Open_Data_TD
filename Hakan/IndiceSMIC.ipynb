# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 10)

# %%
df_evolutionSmic = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/OpenData/ProjetGroupe/evolutiondusmic/valeurs_annuelles.csv', sep=';',skiprows=3)

# %%
df_evolutionSmic

# %%
df_evolutionSmic.rename(columns={"Unnamed: 1": "Indice du SMIC brut mensuel", "Unnamed: 2": "Codes"}, inplace=True)

# %%
df_evolutionSmic.columns

# %%
df_evolutionSmic.columns.values

# %%
def pourcentage(x):
  return ((x/147.5) - 1)*100

# %%
pourcentage = df_evolutionSmic['Indice du SMIC brut mensuel'].apply(pourcentage)

# %%
df_evolutionSmic['Indice du SMIC brut mensuel']
# Out:
# 0    163.4
# 1    160.9
# 2    159.0
# 3    156.6
# 4    154.7
# 5    153.3
# 6    152.3
# 7    151.0
# 8    149.5
# 9    147.5
# Name: Indice du SMIC brut mensuel, dtype: float64

# %%
# plt.bar(df_evolutionSmic['Période'], pourcentage)
plt.bar(df_evolutionSmic['Période'], df_evolutionSmic['Indice du SMIC brut mensuel'])
plt.ylim((145,170))
plt.show()

# %%
plt.bar(df_evolutionSmic['Période'], pourcentage)
plt.ylim((0,12))
plt.show()
